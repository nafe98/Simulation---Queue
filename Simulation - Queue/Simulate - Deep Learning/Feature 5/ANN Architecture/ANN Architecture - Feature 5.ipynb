# %% [markdown]
# # Loading the Preprocessed Data

# %%
import os
import numpy as np

# Load the arrays
X_train = np.load('../Dataset/Train Test Dataset - Feature 5/X_train.npy')
X_test = np.load('../Dataset/Train Test Dataset - Feature 5/X_test.npy')
y_train = np.load('../Dataset/Train Test Dataset - Feature 5/y_train.npy')
y_test = np.load('../Dataset/Train Test Dataset - Feature 5/y_test.npy')

# %% [markdown]
# <div style="background-color: #cce5ff; padding: 10px; border: 1px solid #0066cc;">
#     <h2 style="color: #0066cc; font-weight: bold;">Deep Learning Architecture - ANN</h2>
#
# </div>

# %% [markdown]
# # Importing Libraries - Architecture

# %%
import time
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, LeakyReLU

# %% [markdown]
# # 1. Network Initialization

# %%
input_dim = X_train.shape[1]  

batch_size = 1024 
epochs = 500  
learning_rate = 0.0001  
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# # 2. Define Architecture

# %%
ann_model = Sequential([
    
    Dense(2048, input_dim=input_dim, activation='relu'),
    Dense(1024, activation='relu'),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid') 
    
])

# %%
ann_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 2048)              12288
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 2,807,809
# Trainable params: 2,807,809
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 3. Model Compilation

# %%
ann_model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # EarlyStopping Callback

# %%
from keras.callbacks import EarlyStopping

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

# %% [markdown]
# # Model Checkpoints Callback

# %%
import os
from keras.models import load_model
from keras.callbacks import ModelCheckpoint

# %%
checkpoint_path = '/Model Checkpoints/ANN_Model_Checkpoint.h5'

# %% [markdown]
# ### Check if the checkpoint file exists

# %%
if os.path.exists(checkpoint_path):
    print("Loading model from checkpoint...")
    model = load_model(checkpoint_path)
else:
    print("Checkpoint not found. Initializing new model...")

# %% [markdown]
# ### Create the checkpoint callback

# %%
checkpoint = ModelCheckpoint(
    filepath=checkpoint_path, 
    monitor='val_loss', 
    verbose=1, 
    save_best_only=True, 
    mode='min'
)

# %% [markdown]
# # 4. Fit Network

# %%
start_time = time.time()

history = ann_model.fit(X_train, y_train,
                         batch_size=batch_size,
                         epochs=epochs,
                         validation_split=0.1,
                         callbacks=[checkpoint, early_stopping],  
                         verbose=1)

end_time = time.time()

training_time = end_time - start_time
print("Training Time: ", training_time, "seconds")
# Out:
# Epoch 1/500
# The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
# 546/546 [==============================] - 5s 6ms/step - loss: 0.6459 - accuracy: 0.6196 - val_loss: 0.6318 - val_accuracy: 0.6349
# Epoch 2/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.6238 - accuracy: 0.6424 - val_loss: 0.6197 - val_accuracy: 0.6457
# Epoch 3/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.6137 - accuracy: 0.6504 - val_loss: 0.6140 - val_accuracy: 0.6492
# Epoch 4/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.6049 - accuracy: 0.6579 - val_loss: 0.6014 - val_accuracy: 0.6604
# Epoch 5/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5971 - accuracy: 0.6636 - val_loss: 0.5947 - val_accuracy: 0.6665
# Epoch 6/500
# 546/546 [==============================] - 2s 4ms/step - loss: 0.5895 - accuracy: 0.6705 - val_loss: 0.5978 - val_accuracy: 0.6595
# Epoch 7/500
# 546/546 [==============================] - 2s 4ms/step - loss: 0.5817 - accuracy: 0.6766 - val_loss: 0.5884 - val_accuracy: 0.6714
# Epoch 8/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5740 - accuracy: 0.6825 - val_loss: 0.5743 - val_accuracy: 0.6834
# Epoch 9/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5672 - accuracy: 0.6889 - val_loss: 0.5678 - val_accuracy: 0.6874
# Epoch 10/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5601 - accuracy: 0.6937 - val_loss: 0.5699 - val_accuracy: 0.6867
# Epoch 11/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5527 - accuracy: 0.6996 - val_loss: 0.5545 - val_accuracy: 0.6983
# Epoch 12/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5454 - accuracy: 0.7058 - val_loss: 0.5504 - val_accuracy: 0.7034
# Epoch 13/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5397 - accuracy: 0.7101 - val_loss: 0.5455 - val_accuracy: 0.7046
# Epoch 14/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5334 - accuracy: 0.7145 - val_loss: 0.5385 - val_accuracy: 0.7136
# Epoch 15/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5275 - accuracy: 0.7191 - val_loss: 0.5352 - val_accuracy: 0.7132
# Epoch 16/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5214 - accuracy: 0.7236 - val_loss: 0.5284 - val_accuracy: 0.7197
# Epoch 17/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5149 - accuracy: 0.7285 - val_loss: 0.5243 - val_accuracy: 0.7209
# Epoch 18/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5100 - accuracy: 0.7321 - val_loss: 0.5180 - val_accuracy: 0.7264
# Epoch 19/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5046 - accuracy: 0.7356 - val_loss: 0.5165 - val_accuracy: 0.7278
# Epoch 20/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.5005 - accuracy: 0.7387 - val_loss: 0.5104 - val_accuracy: 0.7317
# Epoch 21/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4943 - accuracy: 0.7428 - val_loss: 0.5101 - val_accuracy: 0.7345
# Epoch 22/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4895 - accuracy: 0.7464 - val_loss: 0.5002 - val_accuracy: 0.7407
# Epoch 23/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4854 - accuracy: 0.7491 - val_loss: 0.5020 - val_accuracy: 0.7375
# Epoch 24/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4801 - accuracy: 0.7528 - val_loss: 0.4957 - val_accuracy: 0.7446
# Epoch 25/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4766 - accuracy: 0.7550 - val_loss: 0.4984 - val_accuracy: 0.7403
# Epoch 26/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4722 - accuracy: 0.7582 - val_loss: 0.4937 - val_accuracy: 0.7438
# Epoch 27/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4678 - accuracy: 0.7612 - val_loss: 0.4888 - val_accuracy: 0.7490
# Epoch 28/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4637 - accuracy: 0.7639 - val_loss: 0.4919 - val_accuracy: 0.7467
# Epoch 29/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4593 - accuracy: 0.7669 - val_loss: 0.4783 - val_accuracy: 0.7556
# Epoch 30/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4566 - accuracy: 0.7677 - val_loss: 0.4773 - val_accuracy: 0.7552
# Epoch 31/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4526 - accuracy: 0.7711 - val_loss: 0.4751 - val_accuracy: 0.7575
# Epoch 32/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4480 - accuracy: 0.7740 - val_loss: 0.4737 - val_accuracy: 0.7611
# Epoch 33/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4459 - accuracy: 0.7753 - val_loss: 0.4772 - val_accuracy: 0.7550
# Epoch 34/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4425 - accuracy: 0.7773 - val_loss: 0.4734 - val_accuracy: 0.7591
# Epoch 35/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4379 - accuracy: 0.7807 - val_loss: 0.4636 - val_accuracy: 0.7653
# Epoch 36/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4348 - accuracy: 0.7823 - val_loss: 0.4566 - val_accuracy: 0.7706
# Epoch 37/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4324 - accuracy: 0.7841 - val_loss: 0.4606 - val_accuracy: 0.7658
# Epoch 38/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4285 - accuracy: 0.7871 - val_loss: 0.4709 - val_accuracy: 0.7614
# Epoch 39/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4259 - accuracy: 0.7887 - val_loss: 0.4593 - val_accuracy: 0.7681
# Epoch 40/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4232 - accuracy: 0.7896 - val_loss: 0.4616 - val_accuracy: 0.7676
# Epoch 41/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4200 - accuracy: 0.7920 - val_loss: 0.4567 - val_accuracy: 0.7733
# Epoch 42/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4173 - accuracy: 0.7940 - val_loss: 0.4461 - val_accuracy: 0.7766
# Epoch 43/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4144 - accuracy: 0.7960 - val_loss: 0.4493 - val_accuracy: 0.7753
# Epoch 44/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4104 - accuracy: 0.7981 - val_loss: 0.4440 - val_accuracy: 0.7788
# Epoch 45/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4094 - accuracy: 0.7989 - val_loss: 0.4420 - val_accuracy: 0.7796
# Epoch 46/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4074 - accuracy: 0.8003 - val_loss: 0.4422 - val_accuracy: 0.7827
# Epoch 47/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4042 - accuracy: 0.8016 - val_loss: 0.4559 - val_accuracy: 0.7727
# Epoch 48/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.4006 - accuracy: 0.8043 - val_loss: 0.4343 - val_accuracy: 0.7856
# Epoch 49/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3976 - accuracy: 0.8067 - val_loss: 0.4349 - val_accuracy: 0.7831
# Epoch 50/500
# 546/546 [==============================] - 2s 4ms/step - loss: 0.3951 - accuracy: 0.8075 - val_loss: 0.4345 - val_accuracy: 0.7833
# Epoch 51/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3945 - accuracy: 0.8075 - val_loss: 0.4275 - val_accuracy: 0.7894
# Epoch 52/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3904 - accuracy: 0.8105 - val_loss: 0.4310 - val_accuracy: 0.7870
# Epoch 53/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3878 - accuracy: 0.8123 - val_loss: 0.4490 - val_accuracy: 0.7761
# Epoch 54/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3857 - accuracy: 0.8135 - val_loss: 0.4221 - val_accuracy: 0.7923
# Epoch 55/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3833 - accuracy: 0.8145 - val_loss: 0.4335 - val_accuracy: 0.7858
# Epoch 56/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3837 - accuracy: 0.8144 - val_loss: 0.4144 - val_accuracy: 0.7979
# Epoch 57/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3782 - accuracy: 0.8182 - val_loss: 0.4187 - val_accuracy: 0.7954
# Epoch 58/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3767 - accuracy: 0.8189 - val_loss: 0.4270 - val_accuracy: 0.7888
# Epoch 59/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3742 - accuracy: 0.8198 - val_loss: 0.4376 - val_accuracy: 0.7869
# Epoch 60/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3730 - accuracy: 0.8209 - val_loss: 0.4239 - val_accuracy: 0.7927
# Epoch 61/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3708 - accuracy: 0.8224 - val_loss: 0.4180 - val_accuracy: 0.7962
# Epoch 62/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3680 - accuracy: 0.8235 - val_loss: 0.4137 - val_accuracy: 0.7992
# Epoch 63/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3659 - accuracy: 0.8250 - val_loss: 0.4133 - val_accuracy: 0.7984
# Epoch 64/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3657 - accuracy: 0.8255 - val_loss: 0.4073 - val_accuracy: 0.8024
# Epoch 65/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3609 - accuracy: 0.8277 - val_loss: 0.4174 - val_accuracy: 0.7946
# Epoch 66/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3606 - accuracy: 0.8278 - val_loss: 0.4215 - val_accuracy: 0.7973
# Epoch 67/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3580 - accuracy: 0.8297 - val_loss: 0.4080 - val_accuracy: 0.8014
# Epoch 68/500
# 546/546 [==============================] - 3s 6ms/step - loss: 0.3565 - accuracy: 0.8305 - val_loss: 0.4091 - val_accuracy: 0.8040
# Epoch 69/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3540 - accuracy: 0.8314 - val_loss: 0.4353 - val_accuracy: 0.7870
# Epoch 70/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3531 - accuracy: 0.8320 - val_loss: 0.4112 - val_accuracy: 0.7996
# Epoch 71/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3510 - accuracy: 0.8334 - val_loss: 0.4089 - val_accuracy: 0.8039
# Epoch 72/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3491 - accuracy: 0.8349 - val_loss: 0.4002 - val_accuracy: 0.8071
# Epoch 73/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3468 - accuracy: 0.8362 - val_loss: 0.4054 - val_accuracy: 0.8036
# Epoch 74/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3437 - accuracy: 0.8377 - val_loss: 0.3990 - val_accuracy: 0.8100
# Epoch 75/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3436 - accuracy: 0.8380 - val_loss: 0.3995 - val_accuracy: 0.8080
# Epoch 76/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3411 - accuracy: 0.8396 - val_loss: 0.4051 - val_accuracy: 0.8053
# Epoch 77/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3388 - accuracy: 0.8411 - val_loss: 0.3994 - val_accuracy: 0.8088
# Epoch 78/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3387 - accuracy: 0.8407 - val_loss: 0.4082 - val_accuracy: 0.8054
# Epoch 79/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3352 - accuracy: 0.8427 - val_loss: 0.3962 - val_accuracy: 0.8112
# Epoch 80/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3322 - accuracy: 0.8443 - val_loss: 0.3862 - val_accuracy: 0.8167
# Epoch 81/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3328 - accuracy: 0.8435 - val_loss: 0.3913 - val_accuracy: 0.8156
# Epoch 82/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3319 - accuracy: 0.8442 - val_loss: 0.3936 - val_accuracy: 0.8124
# Epoch 83/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3301 - accuracy: 0.8450 - val_loss: 0.3867 - val_accuracy: 0.8146
# Epoch 84/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3285 - accuracy: 0.8467 - val_loss: 0.3928 - val_accuracy: 0.8139
# Epoch 85/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3263 - accuracy: 0.8476 - val_loss: 0.3943 - val_accuracy: 0.8111
# Epoch 86/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3257 - accuracy: 0.8477 - val_loss: 0.3909 - val_accuracy: 0.8148
# Epoch 87/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3242 - accuracy: 0.8487 - val_loss: 0.4097 - val_accuracy: 0.8022
# Epoch 88/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3222 - accuracy: 0.8501 - val_loss: 0.3791 - val_accuracy: 0.8211
# Epoch 89/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3224 - accuracy: 0.8501 - val_loss: 0.3857 - val_accuracy: 0.8175
# Epoch 90/500
# 546/546 [==============================] - 2s 5ms/step - loss: 0.3178 - accuracy: 0.8526 - val_loss: 0.3845 - val_accuracy: 0.8187
# Epoch 91/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3162 - accuracy: 0.8528 - val_loss: 0.3942 - val_accuracy: 0.8132
# Epoch 92/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3167 - accuracy: 0.8527 - val_loss: 0.3874 - val_accuracy: 0.8162
# Epoch 93/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3124 - accuracy: 0.8551 - val_loss: 0.3814 - val_accuracy: 0.8208
# Epoch 94/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3115 - accuracy: 0.8560 - val_loss: 0.3780 - val_accuracy: 0.8253
# Epoch 95/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3132 - accuracy: 0.8546 - val_loss: 0.3967 - val_accuracy: 0.8121
# Epoch 96/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3076 - accuracy: 0.8581 - val_loss: 0.3886 - val_accuracy: 0.8205
# Epoch 97/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3078 - accuracy: 0.8578 - val_loss: 0.3752 - val_accuracy: 0.8247
# Epoch 98/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3077 - accuracy: 0.8583 - val_loss: 0.3839 - val_accuracy: 0.8205
# Epoch 99/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3051 - accuracy: 0.8596 - val_loss: 0.3782 - val_accuracy: 0.8244
# Epoch 100/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3079 - accuracy: 0.8581 - val_loss: 0.3799 - val_accuracy: 0.8244
# Epoch 101/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3034 - accuracy: 0.8602 - val_loss: 0.3942 - val_accuracy: 0.8176
# Epoch 102/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3014 - accuracy: 0.8619 - val_loss: 0.3772 - val_accuracy: 0.8249
# Epoch 103/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.3011 - accuracy: 0.8613 - val_loss: 0.3675 - val_accuracy: 0.8276
# Epoch 104/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2968 - accuracy: 0.8641 - val_loss: 0.3751 - val_accuracy: 0.8268
# Epoch 105/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2967 - accuracy: 0.8643 - val_loss: 0.3640 - val_accuracy: 0.8309
# Epoch 106/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2978 - accuracy: 0.8634 - val_loss: 0.3677 - val_accuracy: 0.8305
# Epoch 107/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2938 - accuracy: 0.8651 - val_loss: 0.3851 - val_accuracy: 0.8248
# Epoch 108/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2945 - accuracy: 0.8648 - val_loss: 0.3711 - val_accuracy: 0.8289
# Epoch 109/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2903 - accuracy: 0.8676 - val_loss: 0.3991 - val_accuracy: 0.8143
# Epoch 110/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2927 - accuracy: 0.8662 - val_loss: 0.3688 - val_accuracy: 0.8300
# Epoch 111/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2920 - accuracy: 0.8665 - val_loss: 0.3809 - val_accuracy: 0.8250
# Epoch 112/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2909 - accuracy: 0.8672 - val_loss: 0.3644 - val_accuracy: 0.8321
# Epoch 113/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2846 - accuracy: 0.8703 - val_loss: 0.3721 - val_accuracy: 0.8308
# Epoch 114/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2866 - accuracy: 0.8696 - val_loss: 0.3739 - val_accuracy: 0.8306
# Epoch 115/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2848 - accuracy: 0.8703 - val_loss: 0.3969 - val_accuracy: 0.8143
# Epoch 116/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2834 - accuracy: 0.8711 - val_loss: 0.3578 - val_accuracy: 0.8358
# Epoch 117/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2826 - accuracy: 0.8715 - val_loss: 0.3715 - val_accuracy: 0.8321
# Epoch 118/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2850 - accuracy: 0.8705 - val_loss: 0.3647 - val_accuracy: 0.8347
# Epoch 119/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2773 - accuracy: 0.8747 - val_loss: 0.3758 - val_accuracy: 0.8305
# Epoch 120/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2773 - accuracy: 0.8743 - val_loss: 0.3666 - val_accuracy: 0.8323
# Epoch 121/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2776 - accuracy: 0.8742 - val_loss: 0.3578 - val_accuracy: 0.8368
# Epoch 122/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2796 - accuracy: 0.8732 - val_loss: 0.3632 - val_accuracy: 0.8339
# Epoch 123/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2726 - accuracy: 0.8766 - val_loss: 0.3737 - val_accuracy: 0.8332
# Epoch 124/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2763 - accuracy: 0.8748 - val_loss: 0.3888 - val_accuracy: 0.8185
# Epoch 125/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2759 - accuracy: 0.8752 - val_loss: 0.3674 - val_accuracy: 0.8340
# Epoch 126/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2729 - accuracy: 0.8765 - val_loss: 0.3616 - val_accuracy: 0.8376
# Epoch 127/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2713 - accuracy: 0.8778 - val_loss: 0.3629 - val_accuracy: 0.8329
# Epoch 128/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2708 - accuracy: 0.8780 - val_loss: 0.3644 - val_accuracy: 0.8347
# Epoch 129/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2680 - accuracy: 0.8794 - val_loss: 0.3693 - val_accuracy: 0.8343
# Epoch 130/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2713 - accuracy: 0.8777 - val_loss: 0.3713 - val_accuracy: 0.8346
# Epoch 131/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2677 - accuracy: 0.8800 - val_loss: 0.3601 - val_accuracy: 0.8388
# Epoch 132/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2667 - accuracy: 0.8797 - val_loss: 0.3980 - val_accuracy: 0.8176
# Epoch 133/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2644 - accuracy: 0.8816 - val_loss: 0.3580 - val_accuracy: 0.8389
# Epoch 134/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2656 - accuracy: 0.8805 - val_loss: 0.3677 - val_accuracy: 0.8341
# Epoch 135/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2619 - accuracy: 0.8825 - val_loss: 0.3725 - val_accuracy: 0.8338
# Epoch 136/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2639 - accuracy: 0.8811 - val_loss: 0.3628 - val_accuracy: 0.8404
# Epoch 137/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2633 - accuracy: 0.8815 - val_loss: 0.3664 - val_accuracy: 0.8381
# Epoch 138/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2588 - accuracy: 0.8836 - val_loss: 0.3511 - val_accuracy: 0.8425
# Epoch 139/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2591 - accuracy: 0.8845 - val_loss: 0.3514 - val_accuracy: 0.8441
# Epoch 140/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2591 - accuracy: 0.8838 - val_loss: 0.3505 - val_accuracy: 0.8445
# Epoch 141/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2576 - accuracy: 0.8847 - val_loss: 0.3427 - val_accuracy: 0.8466
# Epoch 142/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2579 - accuracy: 0.8846 - val_loss: 0.3613 - val_accuracy: 0.8426
# Epoch 143/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2553 - accuracy: 0.8861 - val_loss: 0.3691 - val_accuracy: 0.8368
# Epoch 144/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2506 - accuracy: 0.8884 - val_loss: 0.3799 - val_accuracy: 0.8327
# Epoch 145/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2546 - accuracy: 0.8855 - val_loss: 0.3674 - val_accuracy: 0.8323
# Epoch 146/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2533 - accuracy: 0.8872 - val_loss: 0.3976 - val_accuracy: 0.8244
# Epoch 147/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2515 - accuracy: 0.8876 - val_loss: 0.3606 - val_accuracy: 0.8377
# Epoch 148/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2494 - accuracy: 0.8886 - val_loss: 0.3561 - val_accuracy: 0.8449
# Epoch 149/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2507 - accuracy: 0.8881 - val_loss: 0.3398 - val_accuracy: 0.8490
# Epoch 150/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2458 - accuracy: 0.8911 - val_loss: 0.3666 - val_accuracy: 0.8367
# Epoch 151/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2464 - accuracy: 0.8904 - val_loss: 0.3613 - val_accuracy: 0.8435
# Epoch 152/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2463 - accuracy: 0.8907 - val_loss: 0.3488 - val_accuracy: 0.8485
# Epoch 153/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2461 - accuracy: 0.8904 - val_loss: 0.3477 - val_accuracy: 0.8468
# Epoch 154/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2449 - accuracy: 0.8911 - val_loss: 0.3712 - val_accuracy: 0.8368
# Epoch 155/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2457 - accuracy: 0.8911 - val_loss: 0.3759 - val_accuracy: 0.8368
# Epoch 156/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2425 - accuracy: 0.8925 - val_loss: 0.3332 - val_accuracy: 0.8529
# Epoch 157/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2421 - accuracy: 0.8927 - val_loss: 0.3369 - val_accuracy: 0.8502
# Epoch 158/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2431 - accuracy: 0.8923 - val_loss: 0.3388 - val_accuracy: 0.8524
# Epoch 159/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2386 - accuracy: 0.8943 - val_loss: 0.3376 - val_accuracy: 0.8551
# Epoch 160/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2355 - accuracy: 0.8959 - val_loss: 0.3467 - val_accuracy: 0.8507
# Epoch 161/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2429 - accuracy: 0.8920 - val_loss: 0.3529 - val_accuracy: 0.8498
# Epoch 162/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2359 - accuracy: 0.8956 - val_loss: 0.3505 - val_accuracy: 0.8476
# Epoch 163/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2409 - accuracy: 0.8931 - val_loss: 0.3509 - val_accuracy: 0.8458
# Epoch 164/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2338 - accuracy: 0.8970 - val_loss: 0.3523 - val_accuracy: 0.8478
# Epoch 165/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2323 - accuracy: 0.8975 - val_loss: 0.3449 - val_accuracy: 0.8492
# Epoch 166/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2333 - accuracy: 0.8965 - val_loss: 0.3529 - val_accuracy: 0.8487
# Epoch 167/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2329 - accuracy: 0.8968 - val_loss: 0.3392 - val_accuracy: 0.8548
# Epoch 168/500
# 546/546 [==============================] - 2s 4ms/step - loss: 0.2331 - accuracy: 0.8967 - val_loss: 0.3486 - val_accuracy: 0.8469
# Epoch 169/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2338 - accuracy: 0.8969 - val_loss: 0.3380 - val_accuracy: 0.8525
# Epoch 170/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2277 - accuracy: 0.8999 - val_loss: 0.3385 - val_accuracy: 0.8544
# Epoch 171/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2294 - accuracy: 0.8992 - val_loss: 0.3498 - val_accuracy: 0.8500
# Epoch 172/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2320 - accuracy: 0.8974 - val_loss: 0.3431 - val_accuracy: 0.8541
# Epoch 173/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2299 - accuracy: 0.8986 - val_loss: 0.3470 - val_accuracy: 0.8517
# Epoch 174/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2261 - accuracy: 0.9005 - val_loss: 0.3436 - val_accuracy: 0.8545
# Epoch 175/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2243 - accuracy: 0.9015 - val_loss: 0.3429 - val_accuracy: 0.8559
# Epoch 176/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2274 - accuracy: 0.9000 - val_loss: 0.3438 - val_accuracy: 0.8523
# Epoch 177/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2250 - accuracy: 0.9012 - val_loss: 0.3489 - val_accuracy: 0.8524
# Epoch 178/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2264 - accuracy: 0.9010 - val_loss: 0.3247 - val_accuracy: 0.8600
# Epoch 179/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2227 - accuracy: 0.9023 - val_loss: 0.3299 - val_accuracy: 0.8587
# Epoch 180/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2228 - accuracy: 0.9023 - val_loss: 0.3341 - val_accuracy: 0.8560
# Epoch 181/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2216 - accuracy: 0.9034 - val_loss: 0.3569 - val_accuracy: 0.8495
# Epoch 182/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2267 - accuracy: 0.9003 - val_loss: 0.3481 - val_accuracy: 0.8520
# Epoch 183/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2150 - accuracy: 0.9059 - val_loss: 0.3411 - val_accuracy: 0.8532
# Epoch 184/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2170 - accuracy: 0.9058 - val_loss: 0.3354 - val_accuracy: 0.8567
# Epoch 185/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2204 - accuracy: 0.9033 - val_loss: 0.3583 - val_accuracy: 0.8495
# Epoch 186/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2169 - accuracy: 0.9050 - val_loss: 0.3391 - val_accuracy: 0.8576
# Epoch 187/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2179 - accuracy: 0.9045 - val_loss: 0.3454 - val_accuracy: 0.8541
# Epoch 188/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2167 - accuracy: 0.9055 - val_loss: 0.3566 - val_accuracy: 0.8504
# Epoch 189/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2145 - accuracy: 0.9066 - val_loss: 0.3299 - val_accuracy: 0.8591
# Epoch 190/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2161 - accuracy: 0.9058 - val_loss: 0.3644 - val_accuracy: 0.8465
# Epoch 191/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2174 - accuracy: 0.9052 - val_loss: 0.3444 - val_accuracy: 0.8561
# Epoch 192/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2141 - accuracy: 0.9074 - val_loss: 0.3429 - val_accuracy: 0.8564
# Epoch 193/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2154 - accuracy: 0.9063 - val_loss: 0.4258 - val_accuracy: 0.8288
# Epoch 194/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2121 - accuracy: 0.9081 - val_loss: 0.3417 - val_accuracy: 0.8588
# Epoch 195/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2104 - accuracy: 0.9083 - val_loss: 0.3510 - val_accuracy: 0.8502
# Epoch 196/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2098 - accuracy: 0.9087 - val_loss: 0.3458 - val_accuracy: 0.8537
# Epoch 197/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2115 - accuracy: 0.9084 - val_loss: 0.3613 - val_accuracy: 0.8542
# Epoch 198/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2105 - accuracy: 0.9084 - val_loss: 0.3449 - val_accuracy: 0.8540
# Epoch 199/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2083 - accuracy: 0.9100 - val_loss: 0.3484 - val_accuracy: 0.8523
# Epoch 200/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2091 - accuracy: 0.9091 - val_loss: 0.3327 - val_accuracy: 0.8607
# Epoch 201/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2097 - accuracy: 0.9091 - val_loss: 0.3247 - val_accuracy: 0.8642
# Epoch 202/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2064 - accuracy: 0.9105 - val_loss: 0.3462 - val_accuracy: 0.8546
# Epoch 203/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2042 - accuracy: 0.9115 - val_loss: 0.3460 - val_accuracy: 0.8576
# Epoch 204/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2058 - accuracy: 0.9106 - val_loss: 0.3629 - val_accuracy: 0.8533
# Epoch 205/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2039 - accuracy: 0.9117 - val_loss: 0.3302 - val_accuracy: 0.8626
# Epoch 206/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2030 - accuracy: 0.9122 - val_loss: 0.3508 - val_accuracy: 0.8573
# Epoch 207/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2072 - accuracy: 0.9105 - val_loss: 0.3381 - val_accuracy: 0.8586
# Epoch 208/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2011 - accuracy: 0.9132 - val_loss: 0.3285 - val_accuracy: 0.8644
# Epoch 209/500
# 546/546 [==============================] - 2s 5ms/step - loss: 0.1990 - accuracy: 0.9140 - val_loss: 0.3392 - val_accuracy: 0.8584
# Epoch 210/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2018 - accuracy: 0.9128 - val_loss: 0.3411 - val_accuracy: 0.8610
# Epoch 211/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2014 - accuracy: 0.9135 - val_loss: 0.3310 - val_accuracy: 0.8619
# Epoch 212/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2015 - accuracy: 0.9133 - val_loss: 0.3612 - val_accuracy: 0.8469
# Epoch 213/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1966 - accuracy: 0.9153 - val_loss: 0.3378 - val_accuracy: 0.8650
# Epoch 214/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.2009 - accuracy: 0.9131 - val_loss: 0.3392 - val_accuracy: 0.8652
# Epoch 215/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1976 - accuracy: 0.9146 - val_loss: 0.3993 - val_accuracy: 0.8365
# Epoch 216/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1954 - accuracy: 0.9159 - val_loss: 0.3228 - val_accuracy: 0.8677
# Epoch 217/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1963 - accuracy: 0.9153 - val_loss: 0.3737 - val_accuracy: 0.8525
# Epoch 218/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1982 - accuracy: 0.9146 - val_loss: 0.3523 - val_accuracy: 0.8586
# Epoch 219/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1935 - accuracy: 0.9168 - val_loss: 0.3493 - val_accuracy: 0.8598
# Epoch 220/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1946 - accuracy: 0.9165 - val_loss: 0.3330 - val_accuracy: 0.8645
# Epoch 221/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1942 - accuracy: 0.9164 - val_loss: 0.3452 - val_accuracy: 0.8630
# Epoch 222/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1922 - accuracy: 0.9177 - val_loss: 0.3623 - val_accuracy: 0.8537
# Epoch 223/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1918 - accuracy: 0.9178 - val_loss: 0.3378 - val_accuracy: 0.8625
# Epoch 224/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1955 - accuracy: 0.9159 - val_loss: 0.3390 - val_accuracy: 0.8600
# Epoch 225/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1918 - accuracy: 0.9182 - val_loss: 0.3366 - val_accuracy: 0.8639
# Epoch 226/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1905 - accuracy: 0.9186 - val_loss: 0.3275 - val_accuracy: 0.8659
# Epoch 227/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1864 - accuracy: 0.9200 - val_loss: 0.3305 - val_accuracy: 0.8679
# Epoch 228/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1934 - accuracy: 0.9172 - val_loss: 0.3532 - val_accuracy: 0.8596
# Epoch 229/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1867 - accuracy: 0.9202 - val_loss: 0.3328 - val_accuracy: 0.8678
# Epoch 230/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1886 - accuracy: 0.9196 - val_loss: 0.3467 - val_accuracy: 0.8617
# Epoch 231/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1894 - accuracy: 0.9189 - val_loss: 0.3211 - val_accuracy: 0.8689
# Epoch 232/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1872 - accuracy: 0.9202 - val_loss: 0.3354 - val_accuracy: 0.8650
# Epoch 233/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1871 - accuracy: 0.9203 - val_loss: 0.3182 - val_accuracy: 0.8708
# Epoch 234/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1841 - accuracy: 0.9218 - val_loss: 0.3282 - val_accuracy: 0.8709
# Epoch 235/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1872 - accuracy: 0.9198 - val_loss: 0.3261 - val_accuracy: 0.8672
# Epoch 236/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1854 - accuracy: 0.9209 - val_loss: 0.3394 - val_accuracy: 0.8625
# Epoch 237/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1860 - accuracy: 0.9204 - val_loss: 0.3268 - val_accuracy: 0.8672
# Epoch 238/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1830 - accuracy: 0.9219 - val_loss: 0.3293 - val_accuracy: 0.8678
# Epoch 239/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1833 - accuracy: 0.9218 - val_loss: 0.3397 - val_accuracy: 0.8660
# Epoch 240/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1853 - accuracy: 0.9209 - val_loss: 0.3232 - val_accuracy: 0.8697
# Epoch 241/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1783 - accuracy: 0.9243 - val_loss: 0.3255 - val_accuracy: 0.8699
# Epoch 242/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1819 - accuracy: 0.9229 - val_loss: 0.3451 - val_accuracy: 0.8632
# Epoch 243/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1842 - accuracy: 0.9217 - val_loss: 0.3144 - val_accuracy: 0.8731
# Epoch 244/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1773 - accuracy: 0.9245 - val_loss: 0.3858 - val_accuracy: 0.8429
# Epoch 245/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1808 - accuracy: 0.9229 - val_loss: 0.3246 - val_accuracy: 0.8723
# Epoch 246/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1785 - accuracy: 0.9238 - val_loss: 0.3262 - val_accuracy: 0.8674
# Epoch 247/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1788 - accuracy: 0.9234 - val_loss: 0.3720 - val_accuracy: 0.8535
# Epoch 248/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1759 - accuracy: 0.9249 - val_loss: 0.3378 - val_accuracy: 0.8681
# Epoch 249/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1788 - accuracy: 0.9239 - val_loss: 0.3381 - val_accuracy: 0.8682
# Epoch 250/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1795 - accuracy: 0.9239 - val_loss: 0.3342 - val_accuracy: 0.8722
# Epoch 251/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1750 - accuracy: 0.9255 - val_loss: 0.3352 - val_accuracy: 0.8665
# Epoch 252/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1749 - accuracy: 0.9260 - val_loss: 0.3190 - val_accuracy: 0.8745
# Epoch 253/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1748 - accuracy: 0.9256 - val_loss: 0.3325 - val_accuracy: 0.8696
# Epoch 254/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1791 - accuracy: 0.9238 - val_loss: 0.3406 - val_accuracy: 0.8687
# Epoch 255/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1718 - accuracy: 0.9271 - val_loss: 0.3298 - val_accuracy: 0.8721
# Epoch 256/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1756 - accuracy: 0.9252 - val_loss: 0.3222 - val_accuracy: 0.8732
# Epoch 257/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1712 - accuracy: 0.9276 - val_loss: 0.3265 - val_accuracy: 0.8700
# Epoch 258/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1729 - accuracy: 0.9267 - val_loss: 0.3294 - val_accuracy: 0.8732
# Epoch 259/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1744 - accuracy: 0.9261 - val_loss: 0.3287 - val_accuracy: 0.8741
# Epoch 260/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1725 - accuracy: 0.9271 - val_loss: 0.3487 - val_accuracy: 0.8630
# Epoch 261/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1714 - accuracy: 0.9275 - val_loss: 0.3245 - val_accuracy: 0.8749
# Epoch 262/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1706 - accuracy: 0.9281 - val_loss: 0.3973 - val_accuracy: 0.8461
# Epoch 263/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1697 - accuracy: 0.9284 - val_loss: 0.3364 - val_accuracy: 0.8715
# Epoch 264/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1714 - accuracy: 0.9277 - val_loss: 0.3192 - val_accuracy: 0.8755
# Epoch 265/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1711 - accuracy: 0.9275 - val_loss: 0.3301 - val_accuracy: 0.8727
# Epoch 266/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1666 - accuracy: 0.9294 - val_loss: 0.3204 - val_accuracy: 0.8775
# Epoch 267/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1698 - accuracy: 0.9285 - val_loss: 0.3312 - val_accuracy: 0.8697
# Epoch 268/500
# 546/546 [==============================] - 2s 4ms/step - loss: 0.1665 - accuracy: 0.9297 - val_loss: 0.3205 - val_accuracy: 0.8756
# Epoch 269/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1638 - accuracy: 0.9309 - val_loss: 0.3713 - val_accuracy: 0.8570
# Epoch 270/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1681 - accuracy: 0.9288 - val_loss: 0.3258 - val_accuracy: 0.8737
# Epoch 271/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1647 - accuracy: 0.9305 - val_loss: 0.3240 - val_accuracy: 0.8768
# Epoch 272/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1701 - accuracy: 0.9281 - val_loss: 0.3347 - val_accuracy: 0.8694
# Epoch 273/500
# 546/546 [==============================] - 3s 5ms/step - loss: 0.1639 - accuracy: 0.9308 - val_loss: 0.3219 - val_accuracy: 0.8762
# Training Time:  741.1256296634674 seconds

# %% [markdown]
# # Saving the model and training history

# %%
ann_model.save('ANN_Architecture_5_Features.h5')
np.save('ANN_history_5_Features.npy', history.history)

# %% [markdown]
# # 5. Model Evaluation

# %% [markdown]
# # Importing Libraries - Evaluation

# %%
import seaborn as sns
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %% [markdown]
# # Plotting Loss and Accuracy Curve

# %% [markdown]
# ### Loss Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['loss'], 'r', linewidth=3.0)
plt.plot(history.history['val_loss'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Loss', fontsize=16)

plt.legend(['Training Loss', 'Validation Loss'], fontsize=18)
plt.title('Loss Curve of Artificial Neural Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ### Accuracy Curve

# %%
plt.figure(figsize=[8,6])

plt.plot(history.history['accuracy'], 'r', linewidth=3.0)
plt.plot(history.history['val_accuracy'], 'b', linewidth=3.0)

plt.xlabel('Epochs', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)

plt.legend(['Training Accuracy', 'Validation Accuracy'], fontsize=18)
plt.title('Accuracy Curve of Artificial Neural Network - 5 Features', fontsize=16)

plt.grid(True)
plt.show()

# %% [markdown]
# ###  Make predictions on test data

# %%
y_pred = ann_model.predict(X_test)
y_pred = (y_pred > 0.5).astype(int).flatten()  # Convert probabilities to classes
# Out:
# 4853/4853 [==============================] - 7s 1ms/step

# %% [markdown]
# # Classification Report

# %%
test_loss, test_accuracy = ann_model.evaluate(X_test, y_test, verbose=0)
print(f'Test accuracy: {test_accuracy:.2f}, Test loss: {test_loss:.2f}')
# Out:
# Test accuracy: 0.87, Test loss: 0.32

# %%
classification_report = classification_report(y_test, y_pred)
print(classification_report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87     77676
#            1       0.86      0.88      0.87     77614
#
#     accuracy                           0.87    155290
#    macro avg       0.87      0.87      0.87    155290
# weighted avg       0.87      0.87      0.87    155290

# %% [markdown]
# # Confusion Matrix

# %%
class_labels = ["Alert", "Drowsy"]

conf_matrix = confusion_matrix(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred) * 100

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=True, xticklabels=class_labels, yticklabels=class_labels, linewidths=.5)

plt.title(f'Confusion Matrix ANN - 5 (Accuracy: {accuracy:.2f}%)', fontsize=16)

plt.xlabel('Predicted Label', fontsize=14)
plt.ylabel('True Label', fontsize=14)

plt.xticks(rotation=0, fontsize=12)  
plt.yticks(rotation=0, fontsize=12)  

plt.show()

# %% [markdown]
# # Evaluation Metrics

# %%
# Calculate accuracy, precision, recall, F1-score, AUC-ROC

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
auc_roc = roc_auc_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
print("AUC-ROC:", auc_roc)
# Out:
# Accuracy: 0.8722068388176959
# Precision: 0.8631123738167372
# Recall: 0.8846084469296777
# F1-score: 0.8737282150151754
# AUC-ROC: 0.8722117882210055

# %% [markdown]
# # Receiver Operating Characteristic (ROC) Curve

# %%
roc_data = {}

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(fpr, tpr)
roc_data['ANN - 5'] = {'fpr': fpr, 'tpr': tpr, 'roc_auc': roc_auc}

# Plotting ROC Curves 
plt.figure(figsize=(10, 8))
for name, data in roc_data.items():
    plt.plot(data['fpr'], data['tpr'], lw=2, label=f'{name} (AUC = {data["roc_auc"]:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', lw=2, label='Random Guessing')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate', fontsize=14)
plt.ylabel('True Positive Rate', fontsize=14)
plt.title('Receiver Operating Characteristic (ROC) Curve', fontsize=16)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True)
plt.show()
